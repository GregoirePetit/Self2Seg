# %%
# display /home/gpetit/LIP6/codes/Self2Seg/output/mask_epoch_1.svg

from IPython.display import SVG

SVG(filename='/home/gpetit/LIP6/codes/Self2Seg/output/image_0.02.svg')

# %%
# create a gif 1s per image, and repeat from a list of images /home/gpetit/LIP6/codes/Self2Seg/output/diff1_diff2_1.png, /home/gpetit/LIP6/codes/Self2Seg/output/diff1_diff2_2.png ... /home/gpetit/LIP6/codes/Self2Seg/output/diff1_diff2_10.png
# add a title to the gif with the number of the image
import imageio
import os

images = []
for i in range(1, 11):
    images.append(imageio.imread(f'/home/gpetit/LIP6/codes/Self2Seg/output/diff1_diff2_{i}.png'))


# export the gif
imageio.mimsave('/home/gpetit/LIP6/codes/Self2Seg/output/diff1_diff2.gif', images, duration=100)

# display the gif
from IPython.display import Image
Image(filename='/home/gpetit/LIP6/codes/Self2Seg/output/diff1_diff2.gif')
# Out:
# /tmp/ipykernel_1235/1648692888.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread(f'/home/gpetit/LIP6/codes/Self2Seg/output/diff1_diff2_{i}.png'))
